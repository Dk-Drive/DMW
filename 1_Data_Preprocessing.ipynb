# %%
#import libraries
import pandas as pd
import numpy as np

# %%
#Read data from dataset into dataframe
df = pd.read_csv('world_population.csv')

# %%
#display first 4 rows
df.head()
# Out:
#    Rank CCA3         Country           Capital Continent  2022 Population  \
# 0    36  AFG     Afghanistan             Kabul      Asia         41128771
# 1   138  ALB         Albania            Tirana    Europe          2842321
# 2    34  DZA         Algeria           Algiers    Africa         44903225
# 3   213  ASM  American Samoa         Pago Pago   Oceania            44273
# 4   203  AND         Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
#get information about dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country                      234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
# ...

# %%
# data reduction
# remove/reduce unnecessary arribute from dataframe
subset = df[['Rank', 'Country', 'Capital', 'Continent', '2022 Population', '2020 Population']]
subset.head()
# Out:
#    Rank         Country           Capital Continent  2022 Population  \
# 0    36     Afghanistan             Kabul      Asia         41128771
# 1   138         Albania            Tirana    Europe          2842321
# 2    34         Algeria           Algiers    Africa         44903225
# 3   213  American Samoa         Pago Pago   Oceania            44273
# 4   203         Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population
# 0         38972230
# 1          2866849
# 2         43451666
# 3            46189
# 4            77700

# %%
#data cleaning
# find missing values
subset.isnull().sum()
# Out:
# Rank               0
# Country            0
# Capital            0
# Continent          0
# 2022 Population    0
# 2020 Population    0
# dtype: int64

# %%
#define function for median
def impute_median(series):
  return series.fillna(series.median())

# %%
subset2=df[['Rank','Country','Capital','2022 Population']]
subset2.head()
# Out:
#    Rank         Country           Capital  2022 Population
# 0    36     Afghanistan             Kabul         41128771
# 1   138         Albania            Tirana          2842321
# 2    34         Algeria           Algiers         44903225
# 3   213  American Samoa         Pago Pago            44273
# 4   203         Andorra  Andorra la Vella            79824

# %%
# Data integration
subset3=pd.merge(subset,subset2,on='Country')
subset3.head()
# Out:
#    Rank_x         Country         Capital_x Continent  2022 Population_x  \
# 0      36     Afghanistan             Kabul      Asia           41128771
# 1     138         Albania            Tirana    Europe            2842321
# 2      34         Algeria           Algiers    Africa           44903225
# 3     213  American Samoa         Pago Pago   Oceania              44273
# 4     203         Andorra  Andorra la Vella    Europe              79824
#
#    2020 Population  Rank_y         Capital_y  2022 Population_y
# 0         38972230      36             Kabul           41128771
# 1          2866849     138            Tirana            2842321
# 2         43451666      34           Algiers           44903225
# 3            46189     213         Pago Pago              44273
# 4            77700     203  Andorra la Vella              79824

# %%
#Data Transformation
subset3.to_excel('World_Population.xlsx')
